# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_cloud = pd.read_csv('../Data/downloaded/premios_export.csv')

df_local = pd.read_csv('../Data/processed/premios.csv')

# %%
df_cloud.sort_values(by='numero_sorteo', inplace=True)
df_local.sort_values(by='numero_sorteo', inplace=True)

# %%
df_cloud = df_cloud.drop(columns='id')
df_cloud
# Out:
#        numero_sorteo  numero_premiado letras   monto vendedor ciudad  \
# 49               390             3129     TT  1000.0      NaN    NaN
# 48               390             3080     DT   600.0      NaN    NaN
# 47               390             2980     DT   600.0      NaN    NaN
# 46               390             2885     TT   900.0      NaN    NaN
# 45               390             2880     DT   600.0      NaN    NaN
# ...              ...              ...    ...     ...      ...    ...
# 30456           3069            30000      C   700.0      NaN    NaN
# 30455           3069            29999      C   700.0      NaN    NaN
# 30454           3069            29998      C   700.0      NaN    NaN
# 30438           3069            29982     CR   770.0      NaN    NaN
# 30421           3069            29965      C   700.0      NaN    NaN
#
#       departamento
# 49             NaN
# 48             NaN
# 47             NaN
# 46             NaN
# 45             NaN
# ...            ...
# 30456          NaN
# 30455          NaN
# 30454          NaN
# 30438          NaN
# 30421          NaN
#
# [33071 rows x 7 columns]

# %%
df_local
# Out:
#        numero_sorteo  numero_premiado letras   monto vendedor ciudad  \
# 49               390             3129     TT  1000.0      NaN    NaN
# 48               390             3080     DT   600.0      NaN    NaN
# 47               390             2980     DT   600.0      NaN    NaN
# 46               390             2885     TT   900.0      NaN    NaN
# 45               390             2880     DT   600.0      NaN    NaN
# ...              ...              ...    ...     ...      ...    ...
# 30456           3069            30000      C   700.0      NaN    NaN
# 30455           3069            29999      C   700.0      NaN    NaN
# 30454           3069            29998      C   700.0      NaN    NaN
# 30438           3069            29982     CR   770.0      NaN    NaN
# 30421           3069            29965      C   700.0      NaN    NaN
#
#       departamento
# 49             NaN
# 48             NaN
# 47             NaN
# 46             NaN
# 45             NaN
# ...            ...
# 30456          NaN
# 30455          NaN
# 30454          NaN
# 30438          NaN
# 30421          NaN
#
# [33071 rows x 7 columns]

# %%
df_cloud.isnull().sum()
# Out:
# numero_sorteo          0
# numero_premiado        0
# letras                 0
# monto                  0
# vendedor           29656
# ciudad             30032
# departamento       30032
# dtype: int64

# %%
df_local.isnull().sum()
# Out:
# numero_sorteo          0
# numero_premiado        0
# letras                 0
# monto                  0
# vendedor           29656
# ciudad             30032
# departamento       30032
# dtype: int64

# %%
df_merged = pd.merge(df_cloud, df_local,
                     on=list(df_cloud.columns),  # all columns must match
                     how="outer",
                     indicator=True)

# Step 3: Filter rows that appear ONLY in the cloud DataFrame
df_only_in_cloud = df_merged[df_merged["_merge"] == "left_only"].drop(columns=["_merge"])

# %%
df_only_in_cloud
# Out:
# Empty DataFrame
# Columns: [numero_sorteo, numero_premiado, letras, monto, vendedor, ciudad, departamento]
# Index: []

# %%
df_only_in_cloud.to_csv("rows_only_in_cloud.csv", index=False)

# %%
df_merged_local = pd.merge(df_local, df_cloud,
                     on=list(df_local.columns),  # all columns must match
                     how="outer",
                     indicator=True)

# Step 3: Filter rows that appear ONLY in the cloud DataFrame
df_only_in_local = df_merged[df_merged["_merge"] == "right_only"].drop(columns=["_merge"])

# %%
df_only_in_local
# Out:
# Empty DataFrame
# Columns: [numero_sorteo, numero_premiado, letras, monto, vendedor, ciudad, departamento]
# Index: []
